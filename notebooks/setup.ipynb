# %%
import os

# %% [markdown]
# # Download the dataset from kaggle

# %%
# !chmod 600  /teamspace/studios/this_studio/.kaggle/kaggle.json

# %%
base_path = "/teamspace/studios/this_studio/see4you/data"
if(not os.path.exists(os.path.join(base_path, "raw"))):
    # !kaggle datasets download -d adityajn105/flickr8k --unzip -p /teamspace/studios/this_studio/see4you/data/raw/

# %% [markdown]
# # Download embeddings

# %%
base_path = "/teamspace/studios/this_studio/see4you"
if(not os.path.exists(os.path.join(base_path, "embeddings"))):
    # Cria a pasta
    # !mkdir -p ../embeddings

    # Baixa o arquivo
    # !wget https://dl.fbaipublicfiles.com/fasttext/vectors-english/wiki-news-300d-1M.vec.zip -P ../embeddings/

    # Descompacta na pasta correta
    # !unzip ../embeddings/wiki-news-300d-1M.vec.zip -d ../embeddings/

    # Lista os arquivos para confirmar
    # !ls -lh ../embeddings/

    # !rm ../embeddings/wiki-news-300d-1M.vec.zip
