# %% [markdown]
# # Download the dataset from kaggle

# %%
import os

# %%
# !pip install kaggle

# %%
base_path = "/teamspace/studios/this_studio/GroupTaskLigia"
if(not os.path.exists(os.path.join(base_path, "data"))):
    # !kaggle datasets download -d adityajn105/flickr8k --unzip -p /teamspace/studios/this_studio/GroupTaskLigia/data/
